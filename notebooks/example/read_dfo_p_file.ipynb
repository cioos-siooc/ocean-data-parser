# %%
# google colab only, install ocean-data-parser
# %pip install git+https://github.com/cioos-siooc/ocean-data-parser.git@add-dfo-nl-p-file-parser
# Out:
# Collecting git+https://github.com/cioos-siooc/ocean-data-parser.git@add-dfo-nl-p-file-parser
#   Cloning https://github.com/cioos-siooc/ocean-data-parser.git (to revision add-dfo-nl-p-file-parser) to /tmp/pip-req-build-2uw_adzs
#   Running command git clone --filter=blob:none --quiet https://github.com/cioos-siooc/ocean-data-parser.git /tmp/pip-req-build-2uw_adzs
#   Running command git checkout -b add-dfo-nl-p-file-parser --track origin/add-dfo-nl-p-file-parser
#   Switched to a new branch 'add-dfo-nl-p-file-parser'
#   Branch 'add-dfo-nl-p-file-parser' set up to track remote branch 'add-dfo-nl-p-file-parser' from 'origin'.
#   Resolved https://github.com/cioos-siooc/ocean-data-parser.git to commit 77a65a4940c0e97b6a757ebdb12078afdddaf290
#   Preparing metadata (setup.py) ... done
# Collecting cioos_data_transform@ git+https://github.com/cioos-siooc/cioos-siooc_data_transform.git@ios-parser-extra-vocabulary#egg=cioos_data_transform&subdirectory=cioos_data_transform (from ocean-data-parser==0.2.0)
#   Cloning https://github.com/cioos-siooc/cioos-siooc_data_transform.git (to revision ios-parser-extra-vocabulary) to /tmp/pip-install-qidpyvja/cioos-data-transform_65dd4d684ae4498c862b5149877b82a0
#   Running command git clone --filter=blob:none --quiet https://github.com/cioos-siooc/cioos-siooc_data_transform.git /tmp/pip-install-qidpyvja/cioos-data-transform_65dd4d684ae4498c862b5149877b82a0
#   Running command git checkout -b ios-parser-extra-vocabulary --track origin/ios-parser-extra-vocabulary
#   Switched to a new branch 'ios-parser-extra-vocabulary'
#   Branch 'ios-parser-extra-vocabulary' set up to track remote branch 'ios-parser-extra-vocabulary' from 'origin'.
#   Resolved https://github.com/cioos-siooc/cioos-siooc_data_transform.git to commit de1ea2c70f38d28c3d700dc394171d293265c359
#   Preparing metadata (setup.py) ... done
# Collecting cioos_data_transform_projects@ git+https://github.com/cioos-siooc/cioos-siooc_data_transform.git@ios-parser-extra-vocabulary#egg=cioos_data_transform_projects&subdirectory=projects (from ocean-data-parser==0.2.0)
#   Cloning https://github.com/cioos-siooc/cioos-siooc_data_transform.git (to revision ios-parser-extra-vocabulary) to /tmp/pip-install-qidpyvja/cioos-data-transform-projects_7d3de6fe80a54a2f981a58e66a8fc18e
#   Running command git clone --filter=blob:none --quiet https://github.com/cioos-siooc/cioos-siooc_data_transform.git /tmp/pip-install-qidpyvja/cioos-data-transform-projects_7d3de6fe80a54a2f981a58e66a8fc18e
#   Running command git checkout -b ios-parser-extra-vocabulary --track origin/ios-parser-extra-vocabulary
#   Switched to a new branch 'ios-parser-extra-vocabulary'
#   Branch 'ios-parser-extra-vocabulary' set up to track remote branch 'ios-parser-extra-vocabulary' from 'origin'.
#   Resolved https://github.com/cioos-siooc/cioos-siooc_data_transform.git to commit de1ea2c70f38d28c3d700dc394171d293265c359
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ocean-data-parser==0.2.0) (1.22.4)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from ocean-data-parser==0.2.0) (2022.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ocean-data-parser==0.2.0) (2.27.1)
# Requirement already satisfied: pandas<2.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from ocean-data-parser==0.2.0) (1.5.3)
# Collecting xmltodict (from ocean-data-parser==0.2.0)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from ocean-data-parser==0.2.0) (4.65.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from ocean-data-parser==0.2.0) (2022.7.1)
# Collecting NetCDF4 (from ocean-data-parser==0.2.0)
#   Downloading netCDF4-1.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 39.8 MB/s eta 0:00:00
# Collecting pynmea2 (from ocean-data-parser==0.2.0)
#   Downloading pynmea2-1.19.0-py3-none-any.whl (30 kB)
# Collecting gsw (from ocean-data-parser==0.2.0)
#   Downloading gsw-3.6.17-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 81.0 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from ocean-data-parser==0.2.0) (0.8.10)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ocean-data-parser==0.2.0) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0,>=1.3->ocean-data-parser==0.2.0) (2.8.2)
# Collecting fortranformat (from cioos_data_transform@ git+https://github.com/cioos-siooc/cioos-siooc_data_transform.git@ios-parser-extra-vocabulary#egg=cioos_data_transform&subdirectory=cioos_data_transform->ocean-data-parser==0.2.0)
#   Downloading fortranformat-2.0.0.tar.gz (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from cioos_data_transform@ git+https://github.com/cioos-siooc/cioos-siooc_data_transform.git@ios-parser-extra-vocabulary#egg=cioos_data_transform&subdirectory=cioos_data_transform->ocean-data-parser==0.2.0) (2.3.0)
# Collecting sentry_sdk (from cioos_data_transform_projects@ git+https://github.com/cioos-siooc/cioos-siooc_data_transform.git@ios-parser-extra-vocabulary#egg=cioos_data_transform_projects&subdirectory=projects->ocean-data-parser==0.2.0)
#   Downloading sentry_sdk-1.27.1-py2.py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.7/211.7 kB 14.5 MB/s eta 0:00:00
# Collecting cftime (from NetCDF4->ocean-data-parser==0.2.0)
#   Downloading cftime-1.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.0 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from NetCDF4->ocean-data-parser==0.2.0) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ocean-data-parser==0.2.0) (1.26.16)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->ocean-data-parser==0.2.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ocean-data-parser==0.2.0) (3.4)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray->ocean-data-parser==0.2.0) (23.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.0,>=1.3->ocean-data-parser==0.2.0) (1.16.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->cioos_data_transform@ git+https://github.com/cioos-siooc/cioos-siooc_data_transform.git@ios-parser-extra-vocabulary#egg=cioos_data_transform&subdirectory=cioos_data_transform->ocean-data-parser==0.2.0) (2.0)
# Building wheels for collected packages: ocean-data-parser, cioos_data_transform, cioos_data_transform_projects, fortranformat
#   Building wheel for ocean-data-parser (setup.py) ... done
#   Created wheel for ocean-data-parser: filename=ocean_data_parser-0.2.0-py3-none-any.whl size=149415 sha256=8b0b19c5cf24b5b0674d21cd02652da9b167105bed9b7cc03dd1ab49c55c97c2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fv7_bwl5/wheels/6f/bd/2e/96d896a2f8d849083484d3a798ff54847288187439e8be2abe
#   Building wheel for cioos_data_transform (setup.py) ... done
#   Created wheel for cioos_data_transform: filename=cioos_data_transform-1.0.0-py3-none-any.whl size=29721 sha256=b7bed0ecb783b1121a5a7a4f1f3b9eb67cc6e211f21d973161119ba2503f6a74
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fv7_bwl5/wheels/8f/5c/11/cdaa38073e37f8df4c837e73fed47d628303183e928b59aee6
#   Building wheel for cioos_data_transform_projects (setup.py) ... done
#   Created wheel for cioos_data_transform_projects: filename=cioos_data_transform_projects-1.0.0-py3-none-any.whl size=43796 sha256=712a27bc0530240cedf30b630f73152f2b26babca34e54f1fbb8451a4eeaaca1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fv7_bwl5/wheels/f8/73/45/10ca05fcdada9df0e3b956147bbbd1b2dfbf066482f7e74552
#   Building wheel for fortranformat (setup.py) ... done
#   Created wheel for fortranformat: filename=fortranformat-2.0.0-py3-none-any.whl size=24535 sha256=3489dae763984941d70022dd26b90841570864d86d45eb5500c4c1c29a914545
#   Stored in directory: /root/.cache/pip/wheels/02/ca/38/f24153dd3ad835514c1cc3fc1d95e461fd120c7d6d308942a8
# Successfully built ocean-data-parser cioos_data_transform cioos_data_transform_projects fortranformat
# Installing collected packages: pynmea2, fortranformat, xmltodict, sentry_sdk, gsw, cftime, NetCDF4, cioos_data_transform, cioos_data_transform_projects, ocean-data-parser
# Successfully installed NetCDF4-1.6.4 cftime-1.6.2 cioos_data_transform-1.0.0 cioos_data_transform_projects-1.0.0 fortranformat-2.0.0 gsw-3.6.17 ocean-data-parser-0.2.0 pynmea2-1.19.0 sentry_sdk-1.27.1 xmltodict-0.13.0

# %%
from ocean_data_parser.read.dfo.p import parser
import requests

# %%
# Download example p-file from github tests
example_file_url = "https://raw.githubusercontent.com/cioos-siooc/ocean-data-parser/add-dfo-nl-p-file-parser/tests/parsers_test_files/dfo/odf/p/ctd/56001001.p2022"
pfile_name = example_file_url.split('/')[-1]
response = requests.get(example_file_url)
response.raise_for_status()
with open(pfile_name,'w') as file_handle:
    file_handle.write(response.text)

# %%
# Read p-file
ds = parser(pfile_name)

# Show p-file xarray.Dataset object
ds
# Out:
# WARNING:ocean_data_parser.read.dfo.p:Unknown p-file shipcode=56
# WARNING:ocean_data_parser.read.dfo.p:No vocabulary is available for variable=sigt
# WARNING:ocean_data_parser.read.dfo.p:Missing vocabulary for p-file variable=sigt
# <xarray.Dataset>
# Dimensions:    (index: 2214)
# Coordinates:
#   * index      (index) int64 0 1 2 3 4 5 6 ... 2208 2209 2210 2211 2212 2213
#     time       datetime64[ns] 2022-04-10T14:06:00
#     latitude   float64 47.55
#     longitude  float64 -51.41
# Data variables: (12/14)
#     scan       (index) int64 2 5 8 11 14 17 ... 10444 10447 10450 10453 10458
#     PRESPR01   (index) float64 5.829 5.862 5.892 5.924 ... 171.6 171.7 171.7
#     TEMPS901   (index) float64 0.5384 0.5385 0.5393 ... 0.4747 0.4747 0.4747
#     CNDCST01   (index) float64 2.714 2.714 2.714 2.715 ... 2.806 2.806 2.806
#     PSALST01   (index) float64 31.92 31.92 31.92 31.92 ... 33.09 33.09 33.09
#     sigt       (index) float64 25.6 25.6 25.6 25.6 ... 26.54 26.54 26.54 26.54
#     ...         ...
#     DWIRRXUD   (index) float64 120.3 120.1 120.3 119.9 ... 0.1085 0.1085 0.1085
#     PHXXZZXX   (index) float64 8.343 8.341 8.341 8.343 ... 8.275 8.275 8.275
#     trp        (index) float64 96.65 96.66 96.65 96.65 ... 96.25 96.25 96.25
#     ATTNZS01   (index) float64 0.1364 0.1361 0.1364 ... 0.1529 0.1529 0.1529
#     CCOMD002   (index) float64 0.2455 0.2455 0.2455 ... 0.7799 0.7388 0.7388
#     DOXYZZ01   (index) float64 8.175 8.175 8.179 8.18 ... 6.996 6.996 6.997
# Attributes: (12/44)
#     station:                 1
#     history:                 2022-05-12T13:39:04Z - >SELECT_PROBE S\n2022-05-...
#     time_coverage_start:     1649599560000000000
#     time_coverage_end:       1649599560000000000
#     time_coverage_duration:  P0DT0H0M0S
#     geospatial_lat_min:      47.54666666666667
#     ...                      ...
#     time:                    2022-04-10T14:06:00Z
#     trip:                    1
#     waves_height:            1
#     waves_period:            8
#     wind_dir:                80
#     wind_speed_knots:        2

# %%
# Plots
ds.plot.scatter(x='TEMPS901',y='PRESPR01',yincrease=False)

# %%
# Save to NetCDF
ds.to_netcdf(pfile_name + '.nc')
